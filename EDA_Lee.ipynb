# %%
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# %%
df = pd.read_json("data/data.json")

# %%
df["fraud"] = df["acct_type"].eq("premium").mul(1)

# %%
df.groupby(["listed", "fraud"]).count()
# Out:
#               acct_type  approx_payout_date  body_length  channels  country  \
# listed fraud
# n      0            277                 277          277       277      277
#        1           1769                1769         1769      1769     1763
# y      0           1687                1687         1687      1687     1682
#        1          10604               10604        10604     10604    10534
#
#               currency  delivery_method  description  email_domain  \
# listed fraud
# n      0           277              277          277           277
#        1          1769             1769         1769          1769
# y      0          1687             1675         1687          1687
#        1         10604            10600        10604         10604
#
#               event_created  event_end  event_published  event_start  \
# listed fraud
# n      0                277        277              275          277
# ...

# %%
df_pay = df["previous_payouts"]

# %%
df["payout_length"] = df["previous_payouts"].str.len()

# %%
df.head()
# Out:
#          acct_type  approx_payout_date  body_length  channels country  \
# 0  fraudster_event          1266062400         3852         5      US
# 1          premium          1296720000         3499         0      US
# 2          premium          1296172800         2601         8      US
# 3          premium          1388966400        12347         6      IE
# 4          premium          1297900800         2417        11      US
#
#   currency  delivery_method  \
# 0      USD              0.0
# 1      USD              1.0
# 2      USD              1.0
# 3      EUR              1.0
# 4      USD              0.0
#
#                                          description  \
# 0  <p><a href="http://s432.photobucket.com/albums...
# 1  <p>Join us for a quick, one-night, community-b...
# 2  <h3><span class="subcategory"><strong>Teacher ...
# 3  <p style="margin-bottom: 1.3em; padding-bottom...
# 4  <p>Writers and filmmakers need to understand t...
#
# ...

# %%
df_fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1964 entries, 0 to 14336
# Data columns (total 45 columns):
# acct_type             1964 non-null object
# approx_payout_date    1964 non-null int64
# body_length           1964 non-null int64
# channels              1964 non-null int64
# country               1959 non-null object
# currency              1964 non-null object
# delivery_method       1952 non-null float64
# description           1964 non-null object
# email_domain          1964 non-null object
# event_created         1964 non-null int64
# event_end             1964 non-null int64
# event_published       1870 non-null float64
# event_start           1964 non-null int64
# fb_published          1964 non-null int64
# gts                   1964 non-null float64
# has_analytics         1964 non-null int64
# has_header            978 non-null float64
# has_logo              1964 non-null int64
# listed                1964 non-null object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14337 entries, 0 to 14336
# Data columns (total 45 columns):
# acct_type             14337 non-null object
# approx_payout_date    14337 non-null int64
# body_length           14337 non-null int64
# channels              14337 non-null int64
# country               14256 non-null object
# currency              14337 non-null object
# delivery_method       14321 non-null float64
# description           14337 non-null object
# email_domain          14337 non-null object
# event_created         14337 non-null int64
# event_end             14337 non-null int64
# event_published       14238 non-null float64
# event_start           14337 non-null int64
# fb_published          14337 non-null int64
# gts                   14337 non-null float64
# has_analytics         14337 non-null int64
# has_header            8928 non-null float64
# has_logo              14337 non-null int64
# listed                14337 non-null object
# ...

# %%
import urllib2
my_json = (urllib2.urlopen("http://galvanize-case-study-on-fraud.herokuapp.com/data_point").read())

# %%
my_json = my_json.decode().replace("'", '"')

# %%
pdprint(my_json)
# Out:
# {
#   "approx_payout_date": 1302307200,
#   "body_length": 3382,
#   "channels": 6,
#   "country": "CA",
#   "currency": "USD",
#   "delivery_method": 3.0,
# ...

# %%
import json
import pandas as pd
mj = json.loads(my_json)
mj["previous_payouts"] = [mj["previous_payouts"]]
df = pd.DataFrame(mj)
# Out:
#    approx_payout_date  body_length  channels country currency  \
# 0          1298678400         2880        10      US      USD
#
#    delivery_method                                        description  \
# 0              1.0  <p><img style="float: right; margin-left: 8px;...
#
#     email_domain  event_created   event_end  event_published  event_start  \
# 0  avyschool.org     1287872464  1298246400     1.287873e+09   1298044800
#
#    fb_published     gts  has_analytics  has_header  has_logo listed  \
# 0             0  1116.0              0         0.0         1      y
#
#                                                 name  name_length  num_order  \
# 0  Level I Avalanche Fundamentals for Snowmobiler...           64          3
#
#    num_payouts  object_id                                           org_desc  \
# 0           19     980707  <p>Since 1962 the Silverton Avalanche School h...
#
#    org_facebook                    org_name  org_twitter payee_name  \
# ...
