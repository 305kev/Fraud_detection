# %%
import cPickle as pickle
import pandas as pd
from build_model import TextClassifier, get_data

with open('model.pkl') as f:
    model = pickle.load(f)

X, y = get_data('data/articles.csv')

print "Accuracy:", model.score(X, y)
print "Predictions:", model.predict(X)
# Out:
# Accuracy: 0.735826417358
# Predictions: ['Business Day' 'U.S.' 'World' ..., 'World' 'U.S.' 'U.S.']

# %%
x2 = "D3.js is a JavaScript library for producing dynamic, interactive data visualizations in web browsers. It makes use of the widely implemented SVG, HTML5, and CSS standards. It is the successor to the earlier "

# %%
import numpy as np
tem = [x2]
#print(X[0:1])
#print(tem)
model.predict(tem)
# Out:
# array(['U.S.'],
#       dtype='|S26')

# %%
isinstance(tem, basestring)
# Out:
# False

# %%
import urllib2
from time import sleep
def read_stream(sleepsec = 1):
    sleep(sleepsec)
    return urllib2.urlopen("http://galvanize-case-study-on-fraud.herokuapp.com/data_point").read()

# %%
read_stream()
# Out:
# '{\n  "approx_payout_date": 1342840500, \n  "body_length": 14147, \n  "channels": 10, \n  "country": "US", \n  "currency": "USD", \n  "delivery_method": 1.0, \n  "description": "<p style=\\"color: #000000; text-align: center;\\"><span style=\\"color: #ffb22c; font-size: large; font-family: \'book antiqua\', palatino;\\"><span style=\\"font-family: \'arial black\', \'avant garde\'; font-size: xx-large;\\">This is the world-famous birthplace of HorseSurfing<span style=\\"font-size: small;\\">&trade;</span>!&nbsp; &nbsp;Experience year \'round horseback riding on the beach and swimming with horses!</span></span></p>\\r\\n<p style=\\"color: #000000; text-align: left;\\"><span style=\\"font-size: medium; color: #ffffff;\\"><span style=\\"font-family: \'book antiqua\', palatino;\\">What a way to experience everything that makes Florida one of the world\'s most desirable vacation destinations! A beautiful beach! Beautiful horses. Beautiful BeachHorse&trade; girls! Dolphins! You\'ll even ride in the calm waters of Palma Sola Bay an</span><span style=\\"font-family: \'book antiqua\', palatino;\\">d learn how to HorseSurf&trade; and HorseSki&trade;! Horsebackriding on the beach is the ultimate vacation treat that you will NEVER forget!</span></span></p>\\r\\n<p style=\\"text-align: left;\\"><span style=\\"font-size: x-small; font-family: arial, helvetica, sans-serif;\\"><span><span style=\\"font-size: xx-small;\\"><img style=\\"border: 1px solid black; display: block; margin-left: auto; margin-right: auto;\\"  alt=\\"Bottlenose Dolphins swimming with horses.\\" width=\\"500px\\" /></span></span></span></p>\\r\\n<p style=\\"text-align: center;\\">&nbsp;</p>\\r\\n<hr style=\\"color: #000000;\\" />\\r\\n<p style=\\"color: #000000;\\">&nbsp;</p>\\r\\n<p class=\\"p1\\" style=\\"text-align: center;\\"><span style=\\"font-size: large; font-family: \'arial black\', \'avant garde\';\\">FREQUENTLY ASKED QUESTIONS</span></p>\\r\\n<p class=\\"p2\\" style=\\"text-align: left;\\"><span style=\\"font-family: \'book antiqua\', palatino; font-size: medium;\\"><span style=\\"color: #ffb22c;\\">I don\'t see a beach ride scheduled on the day/time when I want to ride. Should I call you to ask if there are any other available times?</span>&nbsp;No. This popular and unique riding experience sells out fast, and once an event sells out, we remove it from the website. The dates and times you see on our website are all that we have available. All times are based on low-tide and are only on those days in which low tide occurs during daylight hours. </span><br /> <br /><span style=\\"font-family: \'book antiqua\', palatino; font-size: medium;\\"><span style=\\"color: #ffb22c;\\"> WARNING: Is there anyone else who does this?</span> No. We have no legitimate competitors at the moment; however, we have heard someone is claiming to offer \\"horseback riding tours of Anna Maria Island.\\" They are taking people\'s money and not showing up. Horses are not permitted on AMI\'s beaches. We don\'t know who they are.</span></p>\\r\\n<p class=\\"p2\\" style=\\"text-align: left;\\"><span style=\\"font-family: \'book antiqua\', palatino; font-size: medium;\\"><span style=\\"color: #ffb22c;\\">Who can participate in the beach experience?</span>&nbsp;&nbsp;Almost anyone can do this because we can adjust the ride depending on your experience level. We make it fun for beginners and expert riders alike. Children as young as 3 years old can do this with no diminution whatsoever in the experience. We welcome the disabled. Our only restriction is that you must weigh under 300 lbs. Sorry, no exceptions. Most of our horses are limited to riders who weigh under 220 lbs.</span></p>\\r\\n<p class=\\"p2\\" style=\\"text-align: left;\\"><br /><span style=\\"font-family: \'book antiqua\', palatino; font-size: medium;\\"><span style=\\"color: #ffb22c;\\"> I know how to ride, do I have to have a guide?</span>&nbsp;If you are an \\"expert\\" rider we\'ll let you ride on the beach without a guide,  ...
